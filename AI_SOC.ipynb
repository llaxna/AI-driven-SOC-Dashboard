# %% [markdown]
# <a href="https://colab.research.google.com/github/llaxna/AI-driven-SOC-Dashboard/blob/main/AI_SOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn.metrics import classification_report, roc_auc_score, precision_recall_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.metrics import roc_curve

# %%
import kagglehub

path = kagglehub.dataset_download("chethuhn/network-intrusion-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/network-intrusion-dataset

# %%
os.listdir(path)
# Out:
# ['Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv',
#  'Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv',
#  'Tuesday-WorkingHours.pcap_ISCX.csv',
#  'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv',
#  'Monday-WorkingHours.pcap_ISCX.csv',
#  'Friday-WorkingHours-Morning.pcap_ISCX.csv',
#  'Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv',
#  'Wednesday-workingHours.pcap_ISCX.csv']

# %%
PortScan = pd.read_csv(os.path.join(path, 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv'))
PortScan.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 22         1266342                  41
# 1                 22         1319353                  41
# 2                 22             160                   1
# 3                 22         1303488                  41
# 4              35396              77                   1
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       44                         2664
# 1                       44                         2664
# 2                        1                            0
# 3                       42                         2728
# 4                        2                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          6954                     456
# 1                          6954                     456
# 2                             0                       0
# ...

# %%
DDos = pd.read_csv(os.path.join(path, 'Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv'))
DDos.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              54865               3                   2
# 1              55054             109                   1
# 2              55055              52                   1
# 3              46236              34                   1
# 4              54863               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             6                       6
# 2                             6                       6
# ...

# %%
Friday = pd.read_csv(os.path.join(path, 'Friday-WorkingHours-Morning.pcap_ISCX.csv'))
Friday.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0               3268       112740690                  32
# 1                389       112740560                  32
# 2                  0       113757377                 545
# 3               5355          100126                  22
# 4                  0           54760                   4
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       16                         6448
# 1                       16                         6448
# 2                        0                            0
# 3                        0                          616
# 4                        0                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          1152                     403
# 1                          5056                     403
# 2                             0                       0
# ...

# %%
WebAttacks = pd.read_csv(os.path.join(path, 'Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv'))
WebAttacks.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                389       113095465                  48
# 1                389       113473706                  68
# 2                  0       119945515                 150
# 3                443        60261928                   9
# 4                 53             269                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       24                         9668
# 1                       40                        11364
# 2                        0                            0
# 3                        7                         2330
# 4                        2                          102
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                         10012                     403
# 1                         12718                     403
# 2                             0                       0
# ...

# %%
Infilteration = pd.read_csv(os.path.join(path, 'Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv'))
Infilteration.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 22             166                   1
# 1              60148              83                   1
# 2                123           99947                   1
# 3                123           37017                   1
# 4                  0       111161336                 147
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            0
# 1                        2                            0
# 2                        1                           48
# 3                        1                           48
# 4                        0                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       0
# 1                             0                       0
# 2                            48                      48
# ...

# %%
Wednesday = pd.read_csv(os.path.join(path, 'Wednesday-workingHours.pcap_ISCX.csv'))
Wednesday.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80           38308                   1
# 1                389             479                  11
# 2                 88            1095                  10
# 3                389           15206                  17
# 4                 88            1092                   9
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            6
# 1                        5                          172
# 2                        6                         3150
# 3                       12                         3452
# 4                        6                         3150
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             6                       6
# 1                           326                      79
# 2                          3150                    1575
# ...

# %%
Tuesday = pd.read_csv(os.path.join(path, 'Tuesday-WorkingHours.pcap_ISCX.csv'))
Tuesday.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 88             640                   7
# 1                 88             900                   9
# 2                 88            1205                   7
# 3                 88             511                   7
# 4                 88             773                   9
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        4                          440
# 1                        4                          600
# 2                        4                         2776
# 3                        4                          452
# 4                        4                          612
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                           358                     220
# 1                          2944                     300
# 2                          2830                    1388
# ...

# %%
Monday = pd.read_csv(os.path.join(path, 'Monday-WorkingHours.pcap_ISCX.csv'))
Monday.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              49188               4                   2
# 1              49188               1                   2
# 2              49188               1                   2
# 3              49188               1                   2
# 4              49486               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        0                           12
# 2                        0                           12
# 3                        0                           12
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             0                       6
# 2                             0                       6
# ...

# %%
files = glob.glob(os.path.join(path, "*.csv"))
df = pd.concat([pd.read_csv(file, low_memory=False) for file in files], ignore_index=True)

# %%
df.shape
# Out:
# (2830743, 79)

# %%
df.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2830743 entries, 0 to 2830742
# Data columns (total 79 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Destination Port             int64
#  1   Flow Duration                int64
#  2   Total Fwd Packets            int64
#  3   Total Backward Packets       int64
#  4   Total Length of Fwd Packets  int64
#  5   Total Length of Bwd Packets  int64
#  6   Fwd Packet Length Max        int64
#  7   Fwd Packet Length Min        int64
#  8   Fwd Packet Length Mean       float64
#  9   Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max        int64
#  11  Bwd Packet Length Min        int64
#  12  Bwd Packet Length Mean       float64
#  13  Bwd Packet Length Std        float64
#  14  Flow Bytes/s                 float64
#  15  Flow Packets/s               float64
#  16  Flow IAT Mean                float64
#  17  Flow IAT Std                 float64
# ...

# %%
df.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      2.830743e+06   2.830743e+06       2.830743e+06
# mean       8.071483e+03   1.478566e+07       9.361160e+00
# std        1.828363e+04   3.365374e+07       7.496728e+02
# min        0.000000e+00  -1.300000e+01       1.000000e+00
# 25%        5.300000e+01   1.550000e+02       2.000000e+00
# 50%        8.000000e+01   3.131600e+04       2.000000e+00
# 75%        4.430000e+02   3.204828e+06       5.000000e+00
# max        6.553500e+04   1.200000e+08       2.197590e+05
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            2.830743e+06                 2.830743e+06
# mean             1.039377e+01                 5.493024e+02
# std              9.973883e+02                 9.993589e+03
# min              0.000000e+00                 0.000000e+00
# 25%              1.000000e+00                 1.200000e+01
# 50%              2.000000e+00                 6.200000e+01
# ...

# %%
df = df[df['Flow Duration'] >= 0]
df = df[df['min_seg_size_forward'] >= 0]

# %%
df
# Out:
#          Destination Port  Flow Duration  Total Fwd Packets  \
# 0                      22        1266342                 41
# 1                      22        1319353                 41
# 2                      22            160                  1
# 3                      22        1303488                 41
# 4                   35396             77                  1
# ...                   ...            ...                ...
# 2830738                53          32215                  4
# 2830739                53            324                  2
# 2830740             58030             82                  2
# 2830741                53        1048635                  6
# 2830742                53          94939                  4
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 0                            44                         2664
# 1                            44                         2664
# ...

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df['Flow Packets/s'] = df['Flow Packets/s'].clip(upper=df['Flow Packets/s'].quantile(0.99))

# %%
df['Label'].value_counts()
# Out:
# Label
# BENIGN                        2272947
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# FTP-Patator                      7938
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
df['Label'] = df['Label'].str.replace('�', '-', regex=False)

# %%
df['Label'].value_counts()
# Out:
# Label
# BENIGN                        2272947
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# FTP-Patator                      7938
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack - Brute Force         1507
# Web Attack - XSS                  652
# Infiltration                       36
# Web Attack - Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
df_clean = df.dropna()
df_clean = df_clean.drop_duplicates()
X = df_clean.drop(columns=['Label'])

# %%
print(X.shape)
print(X.dtypes)
# Out:
# (2520656, 78)
# Destination Port                 int64
# Flow Duration                    int64
# Total Fwd Packets                int64
# Total Backward Packets           int64
# Total Length of Fwd Packets      int64
#                                 ...
# Active Min                       int64
# Idle Mean                      float64
# Idle Std                       float64
# Idle Max                         int64
# Idle Min                         int64
# Length: 78, dtype: object

# %%
df_sample = df_clean.sample(frac=0.1, random_state=42)
X = df_sample.select_dtypes(include='number').fillna(0)

# %%
df_sample['Label'].value_counts()
# Out:
# Label
# BENIGN                        209555
# DoS Hulk                       17308
# DDoS                           12806
# PortScan                        9095
# DoS GoldenEye                    999
# FTP-Patator                      566
# DoS Slowhttptest                 528
# DoS slowloris                    500
# SSH-Patator                      281
# Bot                              202
# Web Attack - Brute Force         162
# Web Attack - XSS                  59
# Infiltration                       3
# Web Attack - Sql Injection         1
# Heartbleed                         1
# Name: count, dtype: int64

# %%
corr_matrix = X.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
X.drop(columns=to_drop, inplace=True)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X_scaled)

# %%
X_pca.shape
# Out:
# (252066, 25)

# %%
# Isolation Forest
iso_forest = IsolationForest(n_estimators=200, contamination=0.17, random_state=42)
iso_preds = iso_forest.fit_predict(X_pca)

# Local Outlier Factor
lof = LocalOutlierFactor(n_neighbors=30, contamination=0.17)
lof_preds = lof.fit_predict(X_pca)

# One-Class SVM
oc_svm = OneClassSVM(kernel='rbf', gamma='scale', nu=0.17)
ocsvm_preds = oc_svm.fit_predict(X_pca)

# %%
pred_map = {1: 'Normal', -1: 'Anomaly'}

df_sample['iso_pred'] = iso_preds
df_sample['lof_pred'] = lof_preds
df_sample['ocsvm_pred'] = ocsvm_preds

df_sample['iso_pred'] = df_sample['iso_pred'].map(pred_map)
df_sample['lof_pred'] = df_sample['lof_pred'].map(pred_map)
df_sample['ocsvm_pred'] = df_sample['ocsvm_pred'].map(pred_map)

# %%
print("Isolation Forest Predictions:")
print(df_sample['iso_pred'].value_counts())

print("\nLocal Outlier Factor Predictions:")
print(df_sample['lof_pred'].value_counts())

print("\nOne-Class SVM Predictions:")
print(df_sample['ocsvm_pred'].value_counts())
# Out:
# Isolation Forest Predictions:
# iso_pred
# Normal     209218
# Anomaly     42848
# Name: count, dtype: int64
#
# Local Outlier Factor Predictions:
# lof_pred
# Normal     209214
# Anomaly     42852
# Name: count, dtype: int64
#
# One-Class SVM Predictions:
# ocsvm_pred
# Normal     209216
# Anomaly     42850
# Name: count, dtype: int64

# %%
true_labels = df_sample['Label'].apply(lambda x: 1 if x == 'BENIGN' else -1)

models_preds = {
    'Isolation Forest': df_sample['iso_pred'],
    'Local Outlier Factor': df_sample['lof_pred'],
    'One-Class SVM': df_sample['ocsvm_pred']
}

results = {}

for model_name, preds_str in models_preds.items():
    preds_bin = preds_str.apply(lambda x: 1 if x == 'Normal' else -1)

    report = classification_report(true_labels, preds_bin, output_dict=True, zero_division=0)

    roc_auc = roc_auc_score(true_labels, preds_bin)

    precision, recall, _ = precision_recall_curve(true_labels, preds_bin)
    pr_auc = auc(recall, precision)

    results[model_name] = {
        'F1-score (Anomaly)': report['-1']['f1-score'],
        'Precision (Anomaly)': report['-1']['precision'],
        'Recall (Anomaly)': report['-1']['recall'],
        'F1-score (Normal)': report['1']['f1-score'],
        'Precision (Normal)': report['1']['precision'],
        'Recall (Normal)': report['1']['recall'],
        'ROC-AUC': roc_auc,
        'PR-AUC': pr_auc,
        'Accuracy': report['accuracy']
    }

results_df = pd.DataFrame(results).T
results_df = results_df.round(3)
results_df
# Out:
#                       F1-score (Anomaly)  Precision (Anomaly)  \
# Isolation Forest                   0.362                0.360
# Local Outlier Factor               0.127                0.127
# One-Class SVM                      0.338                0.336
#
#                       Recall (Anomaly)  F1-score (Normal)  Precision (Normal)  \
# Isolation Forest                 0.363              0.870               0.871
# Local Outlier Factor             0.128              0.822               0.823
# One-Class SVM                    0.339              0.865               0.866
#
#                       Recall (Normal)  ROC-AUC  PR-AUC  Accuracy
# Isolation Forest                0.869    0.616   0.924     0.784
# Local Outlier Factor            0.821    0.475   0.896     0.704
# One-Class SVM                   0.864    0.602   0.921     0.776

# %%
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
sns.countplot(x='iso_pred', hue='iso_pred', data=df_sample, palette=['blue', 'red'], legend=False)
plt.title('Isolation Forest Predictions')

plt.subplot(1, 3, 2)
sns.countplot(x='lof_pred', hue='lof_pred', data=df_sample, palette=['blue', 'red'], legend=False)
plt.title('Local Outlier Factor Predictions')

plt.subplot(1, 3, 3)
sns.countplot(x='ocsvm_pred', hue='ocsvm_pred', data=df_sample, palette=['blue', 'red'], legend=False)
plt.title('One-Class SVM Predictions')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_conf_matrix(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred, labels=[-1, 1])
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Pred: Anomaly', 'Pred: Normal'],
                yticklabels=['True: Anomaly', 'True: Normal'])
    plt.title(f'{model_name} Confusion Matrix')
    plt.xlabel('Prediction')
    plt.ylabel('Actual')
    plt.show()

for name, preds_str in models_preds.items():
    preds_bin = preds_str.map({'Anomaly': -1, 'Normal': 1})
    plot_conf_matrix(true_labels, preds_bin, name)

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 5))
models = ['iso_pred', 'lof_pred', 'ocsvm_pred']
titles = ['Isolation Forest', 'Local Outlier Factor', 'One-Class SVM']

for i, model in enumerate(models):
    sns.heatmap(
        pd.crosstab(df_sample['Label'], df_sample[model], normalize='index'),
        annot=True, fmt=".2f", cmap='coolwarm', ax=axs[i]
    )
    axs[i].set_title(f'{titles[i]} Confusion Matrix')
    axs[i].set_xlabel('Predicted')
    axs[i].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
for model_name, preds_str in models_preds.items():
    preds_bin = preds_str.apply(lambda x: 1 if x == 'Normal' else -1)
    fpr, tpr, _ = roc_curve(true_labels, preds_bin)
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {results[model_name]["ROC-AUC"]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
for model_name, preds_str in models_preds.items():
    preds_bin = preds_str.apply(lambda x: 1 if x == 'Normal' else -1)
    precision, recall, _ = precision_recall_curve(true_labels, preds_bin)
    plt.plot(recall, precision, label=f'{model_name} (PR-AUC = {results[model_name]["PR-AUC"]:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend()
plt.grid(True)
plt.show()

# %%
results_df[['F1-score (Anomaly)', 'F1-score (Normal)', 'ROC-AUC', 'PR-AUC']].plot.bar(figsize=(12, 6))
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Best Model: Isolation Forest

# %%
df_sample['best_model_prediction'] = iso_preds
df_sample.to_csv('predictions.csv', index=False)
